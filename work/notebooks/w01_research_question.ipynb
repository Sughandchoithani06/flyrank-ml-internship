# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Sughandchoithani06/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
#
# Honestly the reason is pretty simple — the whole starter pipeline in this repo is already built around this exact question (which pages need a review first), so I already have real numbers to lean on instead of starting from zero. I ran the starter notebooks and saw that a random forest actually beats the hand-written rule by a lot at picking the right pages to flag. That told me there's real signal hiding in this data, not just noise, which makes me feel okay committing the next 7 weeks to it.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# The decision I'm trying to help with: out of a big pile of pages, which ones should someone actually look at first if they only have time for a handful.
#
# Who acts on it: a content or SEO reviewer who doesn't have time to manually check every single page, so they need something to point them at the right ones.
#
# Cost of getting it wrong: if I flag a page as "review this" and it's actually fine, that's wasted time on something low-value. If I miss a page that's genuinely declining, it just keeps losing traffic and nobody notices. Neither one is a disaster on its own, but the whole point of doing this is making sure limited review time isn't wasted — so getting the ranking wrong quietly costs something.
#
# Why data/ML actually helps here: there's stuff like impressions, clicks, position, trend, age, word count already sitting in the data, but no human is going to scroll through thousands of pages comparing all of that by eye. A model can weigh all of it together and rank pages in a way a person just can't do manually.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
# !git clone https://github.com/Sughandchoithani06/flyrank-ml-internship.git
# %cd flyrank-ml-internship

df = pd.read_csv('data/raw/content_refresh_anonymized.csv')

print("Total rows:", len(df))
print("Rows with impressions_90d > 0:", (df['impressions_90d'] > 0).sum())
print("Share of pages currently trending down:", round((df['trend_direction'] == 'down').mean(), 3))
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 119 (delta 35), reused 95 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.84 MiB | 13.39 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# /content/flyrank-ml-internship/flyrank-ml-internship
# Total rows: 30000
# Rows with impressions_90d > 0: 30000
# Share of pages currently trending down: 0.542

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# What I can actually say: this gives a ranked list of pages worth reviewing first, based on things we've actually observed — impressions, clicks, position, trend. It's directional, not proof. Something like "this page shows patterns associated with decline" is fair. "This page is definitely declining because of X" is not.
#
# What I can't say: I can't claim that refreshing a page will fix it — that would need an actual experiment, not just this data. I also can't say anything found here is a real Google ranking factor. The trend label I'm using is based on the current window, not a proven future outcome, unless I build that properly later on. And if I ever end up rebuilding something like a product score, that's background info only — not something I'd treat as the truth.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
